# %% [raw]
# ---
# output-file: polytope.html
# title: Polytope Definition
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Polytope)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### Polytope
#
# >      Polytope (A_in:Union[torch.Tensor,numpy.ndarray],
# >                b_in:Union[torch.Tensor,numpy.ndarray], dtype=torch.float16,
# >                device=None, copy:bool=False, requires_grad:bool=False)
#
# Initialize self.  See help(type(self)) for accurate signature.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | A_in | Union |  | Inequality Restriction Matrix |
# | b_in | Union |  | Inequality Vector |
# | dtype | dtype | torch.float16 | torch dtype |
# | device | NoneType | None | device used cpu or cuda |
# | copy | bool | False | bool for creating a copy of the restrictions |
# | requires_grad | bool | False | If we want to keep the gradient |
# | **Returns** | **None** |  |  |

# %%
#| echo: false
#| output: asis
show_doc(Polytope.cast_precision)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L124){target="_blank" style="float:right; font-size:smaller"}
#
# ### Polytope.cast_precision
#
# >      Polytope.cast_precision (dtype=None)

# %%
#| echo: false
#| output: asis
show_doc(Polytope.send_to_device)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L118){target="_blank" style="float:right; font-size:smaller"}
#
# ### Polytope.send_to_device
#
# >      Polytope.send_to_device (device:str=None)

# %%
#| echo: false
#| output: asis
show_doc(NFDPolytope)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L145){target="_blank" style="float:right; font-size:smaller"}
#
# ### NFDPolytope
#
# >      NFDPolytope (A_in:Union[torch.Tensor,numpy.ndarray],
# >                   b_in:Union[torch.Tensor,numpy.ndarray],
# >                   A_eq:Union[torch.Tensor,numpy.ndarray],
# >                   b_eq:Union[torch.Tensor,numpy.ndarray], dtype=torch.float32,
# >                   device=None, copy:bool=False, requires_grad:bool=False)
#
# Initialize self.  See help(type(self)) for accurate signature.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | A_in | Union |  |  |
# | b_in | Union |  |  |
# | A_eq | Union |  |  |
# | b_eq | Union |  |  |
# | dtype | dtype | torch.float32 | Default dtype for Non-Fully-Dimensioonal Polytopes is 32 bits |
# | device | NoneType | None |  |
# | copy | bool | False |  |
# | requires_grad | bool | False |  |
# ...

# %%
#| echo: false
#| output: asis
show_doc(NFDPolytope.cast_precision)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L191){target="_blank" style="float:right; font-size:smaller"}
#
# ### NFDPolytope.cast_precision
#
# >      NFDPolytope.cast_precision (dtype=None)

# %%
#| echo: false
#| output: asis
show_doc(NFDPolytope.send_to_device)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L181){target="_blank" style="float:right; font-size:smaller"}
#
# ### NFDPolytope.send_to_device
#
# >      NFDPolytope.send_to_device (device:str)

# %%
#| echo: false
#| output: asis
show_doc(NFDPolytope.compute_projection_matrix)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L202){target="_blank" style="float:right; font-size:smaller"}
#
# ### NFDPolytope.compute_projection_matrix
#
# >      NFDPolytope.compute_projection_matrix (device:str,
# >                                             solver_precision=torch.float64)

# %%
#| echo: false
#| output: asis
show_doc(NFDPolytope.project_h)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/polytope.py#L255){target="_blank" style="float:right; font-size:smaller"}
#
# ### NFDPolytope.project_h
#
# >      NFDPolytope.project_h (x)
