# %% [raw]
# ---
# output-file: a_warnings.html
# title: Warnings
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(custom_warning)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/warningss.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### custom_warning
#
# >      custom_warning (message, category, filename, lineno, file=None,
# >                      line=None)

# %%
#| echo: false
#| output: asis
show_doc(custom_warning_format)
# Out:
# ---
#
# [source](https://github.com/sonder-art/mhar/blob/released/mhar/warningss.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### custom_warning_format
#
# >      custom_warning_format (message, category, filename, lineno, line=None)
